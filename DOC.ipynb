# %% [markdown]
# Assignment A4
# This Jupyter Notebook file is very simple. First, a shapefile is loaded using GeoPandas and then visualized.

# %%
import geopandas as gpd
FILE = "D:\PROYECTOS\UAN VILLAVICENCIO\PREDIO EL RINCONCITO - UAN VILLAVICENCIO - copia\7 INFORME\8_1_PLANO PREDIAL"
gdf = gpd.read_file(PLANO PREDIAL.shp)

# %%
gdf.explore()
